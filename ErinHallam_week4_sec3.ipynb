# %% [markdown]
# 1. **What is an algorithm?**  A series of steps to solve a problem
# 2. **Variable names may not start with certain characters - name two.** Can not start with a number, any special character besides a(_) or reserved words(none or not)
# 3. **What is a Semantic error?** When code is grammatically correct but doesnt make sense and doesnt produce the expected results
# 4. **What is the #1 rule of coding / debugging?** COMPLEXITY IS THE ENEMY OF EFFICIENCY
# 5. **List 5 Python reserved words.**
#     + none
#     + T/F
#     + not
#     + and
#     + if
#     + def
#
# PER BRANDON SKIP QUESTIONS 11&12 IN THIS H.W ASSIGNMENT

# %%
a = """ 
Erin Hallam
Favorite food: Way to many to list, but right now at this moment I would have to say Tacos
Dream Job would be A Software Engineer Analyst
"""
print(a)
# Out:
#
# Erin Hallam
# Favorite food: Way to many to list, but right now at this moment I would have to say Tacos
# Dream Job would be A oftware engineer

# %%
b = str("this is a test")
c = int(7521)
d = float(75.1248)
e = bool(10<3)
f = list(["beach towel,", "cooler,", "beach chair", "& sunscreen"])
print ("The length of b is ...", len(b))
print ("The index value of the 4th character = ", b[3])
print ("c is ...", type(c))
print (b,c,d,e,f)
# Out:
# The length of b is ... 14
# The index value of the 4th character =  s
# c is ... <class 'int'>
# this is a test 7521 75.1248 False ['beach towel,', 'cooler,', 'beach chair', '& sunscreen']

# %%
savvy = str("Learning Data Analytics and Python is Awesome!")
print(savvy)
print(savvy[5:23])
print(savvy.replace("Awesome", "great"))
if "Python" in savvy:
    print("Yes Python is in the string")
# Out:
# Learning Data Analytics and Python is Awesome!
# ing Data Analytics
# Learning Data Analytics and Python is great!
# Yes Python is in the string

# %%
x, y, z = "name", "age", "length"
print(x, y, z)

name = "Erin"
age = "42"
length = "5'7"
miniBio = (f"Hi my name is {name}, I am {length} and {age} old today.")
print(miniBio)

age = float(42)
print(age)
# Out:
# name age length
# Hi my name is Erin, I am 5'7 and 42 old today.
# 42.0

# %%
holidaylist1 = ["christmas", "Easter", {"St. Patricks Day" : "3.17"}, "Christmas", "x-mas", "Jesus birthday", "12/25"]
listLength = len(holidaylist1)
print("Size of List ...", listLength)

holidaylist1[1] = ["Spring bunnies"]
print("Second holiday replaced [1]...", holidaylist1)

holidaylist2 = ["New Years", "1/1", "Labor Day", "7.4.2026", "fourth of July"]
print(holidaylist2)


holidaylist1.append ("Thanksgiving") 
holidaylist1.append ({"11/11", "Veterans Day"})
print("NewList ... ", holidaylist1)

holidaylist3 =holidaylist1[3:5]
print(holidaylist3)

holidaylist3 =holidaylist1[3:5] + holidaylist2
print(holidaylist3)



simList = ["Border collie", "Lab", "Pittbull", "rotwieler", "GreatDane", "Weimaraner", "Beagle"]
simList.sort()
# simList.sort(reverse=True)
print("Sorted breeds list ...", simList)

simList2 = simList
print(simList2)

simList3 = [ "Mutt", "greyhound", "Beagle", "Boxer"]
print(simList3)

simList4 = simList2 + simList3
simList4.sort()
print(simList4)
# Out:
# Size of List ... 7
# Second holiday replaced [1]... ['christmas', ['Spring bunnies'], {'St. Patricks Day': '3.17'}, 'Christmas', 'x-mas', 'Jesus birthday', '12/25']
# ['New Years', '1/1', 'Labor Day', '7.4.2026', 'fourth of July']
# NewList ...  ['christmas', ['Spring bunnies'], {'St. Patricks Day': '3.17'}, 'Christmas', 'x-mas', 'Jesus birthday', '12/25', 'Thanksgiving', {'11/11', 'Veterans Day'}]
# ['Christmas', 'x-mas']
# ['Christmas', 'x-mas', 'New Years', '1/1', 'Labor Day', '7.4.2026', 'fourth of July']
# Sorted breeds list ... ['Beagle', 'Border collie', 'GreatDane', 'Lab', 'Pittbull', 'Weimaraner', 'rotwieler']
# ['Beagle', 'Border collie', 'GreatDane', 'Lab', 'Pittbull', 'Weimaraner', 'rotwieler']
# ['Mutt', 'greyhound', 'Beagle', 'Boxer']
# ['Beagle', 'Beagle', 'Border collie', 'Boxer', 'GreatDane', 'Lab', 'Mutt', 'Pittbull', 'Weimaraner', 'greyhound', 'rotwieler']

# %%
# THIS IS 11 AND TO SKIP, I DID SOME OF IT
TT = (789, 'test', 789, 85.247, [17, 'tt', 21], 'Chanceyyyy')
print(TT)

TT2 = TT * 3
print("Multiplied tuple example = ", TT2)
# Out:
# (789, 'test', 789, 85.247, [17, 'tt', 21], 'Chanceyyyy')
# Multiplied tuple example =  (789, 'test', 789, 85.247, [17, 'tt', 21], 'Chanceyyyy', 789, 'test', 789, 85.247, [17, 'tt', 21], 'Chanceyyyy', 789, 'test', 789, 85.247, [17, 'tt', 21], 'Chanceyyyy')

# %%
mydct = {
    "name" :"ryan",
    "number": 12,
    "speed" : 85.47,
    "wins" :True,
    "race" : "test27",
    "lap" : "8675309"}
print(mydct)
print(mydct["lap"])



mydct["name"] = "ERIN"
print("replaced my name...", mydct)

mydct['Favorite color'] = 'Blue'
print('color added to list...', mydct)

mylist = [10, 100, 1000]
mydct['addList'] = mylist
print(mydct)

print(mydct.keys())
print(mydct.values())

mydct2 = mydct.copy()
print(mydct2)

mydct2.popitem()
print(mydct2)

mydct2.clear()
print(mydct2)
# Out:
# {'name': 'ryan', 'number': 12, 'speed': 85.47, 'wins': True, 'race': 'test27', 'lap': '8675309'}
# 8675309
# replaced my name... {'name': 'ERIN', 'number': 12, 'speed': 85.47, 'wins': True, 'race': 'test27', 'lap': '8675309'}
# color added to list... {'name': 'ERIN', 'number': 12, 'speed': 85.47, 'wins': True, 'race': 'test27', 'lap': '8675309', 'Favorite color': 'Blue'}
# {'name': 'ERIN', 'number': 12, 'speed': 85.47, 'wins': True, 'race': 'test27', 'lap': '8675309', 'Favorite color': 'Blue', 'addList': [10, 100, 1000]}
# dict_keys(['name', 'number', 'speed', 'wins', 'race', 'lap', 'Favorite color', 'addList'])
# dict_values(['ERIN', 12, 85.47, True, 'test27', '8675309', 'Blue', [10, 100, 1000]])
# {'name': 'ERIN', 'number': 12, 'speed': 85.47, 'wins': True, 'race': 'test27', 'lap': '8675309', 'Favorite color': 'Blue', 'addList': [10, 100, 1000]}
# {'name': 'ERIN', 'number': 12, 'speed': 85.47, 'wins': True, 'race': 'test27', 'lap': '8675309', 'Favorite color': 'Blue'}
# {}
